# %%
import torch
import json
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification

# %%
from transformers import BertConfig, BertForSequenceClassification
# Load config with the correct vocab size and number of labels used during training
config = BertConfig(
    vocab_size=28996,        # 👈 Your actual vocab size used during training
    num_labels=43            # 👈 Your actual number of classification labels
)
# Build model using that config
model = BertForSequenceClassification(config)
# Load weights
state_dict = torch.load("fifth_epoch.pt", map_location="cpu")
model.load_state_dict(state_dict)
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
print("✅ Model successfully rebuilt and loaded!")
# Out:
# ✅ Model successfully rebuilt and loaded!

# %%
import pandas as pd
test_df = pd.read_json("test.json")
print(test_df.head())        # Preview the first few rows
print(test_df.columns)       # Show the column names
# Out:
#                                              content  \
# 0  Vijay Shinde\nasst. sales manager in M - S PLA...
# 1  Jaykumar Shah\nSales Manager\n\nMumbai, Mahara...
# 2  Raktim Podder\n6+ Exp in banking operations an...
# 3  Bhaskar Gupta\nBusiness Management professiona...
# 4  Rohit Bijlani\nJAVA Developer/Senior Systems E...
#
#                                           annotation  extras  \
# 0  [{'label': ['Email Address'], 'points': [{'sta...     NaN
# 1  [{'label': ['Skills'], 'points': [{'start': 38...     NaN
# 2  [{'label': ['Skills'], 'points': [{'start': 88...     NaN
# 3  [{'label': ['Companies worked at'], 'points': ...     NaN
# 4  [{'label': ['Graduation Year'], 'points': [{'s...     NaN
#
#                                             metadata
# 0  {'first_done_at': 1534860188000, 'last_updated...
# 1  {'first_done_at': 1533400611000, 'last_updated...
# 2  {'first_done_at': 1528734410000, 'last_updated...
# 3  {'first_done_at': 1536754903000, 'last_updated...
# ...

# %%
texts = test_df["content"].tolist()

# %%
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer
import torch
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
class ResumeDataset(Dataset):
    def __init__(self, texts):
        self.texts = texts
    def __len__(self):
        return len(self.texts)
    def __getitem__(self, idx):
        encoding = tokenizer(
            self.texts[idx],
            truncation=True,
            padding="max_length",
            max_length=128,
            return_tensors="pt"
        )
        return {key: val.squeeze(0) for key, val in encoding.items()}
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
# Create dataset and loader
test_dataset = ResumeDataset(texts)
test_loader = DataLoader(test_dataset, batch_size=16)
# Make predictions
model.eval()
all_preds = []
with torch.no_grad():
    for batch in test_loader:
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1).cpu().numpy()
        all_preds.extend(preds)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 12
#       9 input_ids = batch["input_ids"].to(device)
#      10 attention_mask = batch["attention_mask"].to(device)
# ---> 12 outputs = model(input_ids=input_ids, attention_mask=attention_mask)
#      13 logits = outputs.logits
#      14 preds = torch.argmax(logits, dim=1).cpu().numpy()
#
# File ~\anaconda3\envs\tff_en\lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~\anaconda3\envs\tff_en\lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
# ...
